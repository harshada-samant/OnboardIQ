# %%
import duckdb

# %%
duckdb_path = r"D:\onboardingIQ\Onboardiq\data\crm_platform.duckdb"

# %%
con = duckdb.connect(duckdb_path)

# %%
con.close()

# %%
df = con.execute("SELECT * from asset").fetchdf()

# %%
df.dtypes
# Out:
# c_asset_id                  str
# b_location_id               str
# asset_type                  str
# status                      str
# purchase_date    datetime64[us]
# cost                    float64
# dtype: object
